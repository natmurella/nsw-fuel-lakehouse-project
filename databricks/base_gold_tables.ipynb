# %%
catalog = "fuel"
# gold tables
gold_station_latest_price_table = f"{catalog}.gold.station_latest_price"

# %%
# wipe and drop gold tables
spark.sql(f"DROP TABLE IF EXISTS {gold_station_latest_price_table}")
# Out:
# DataFrame[]

# %%
# gold table schema define by pipeline if missing.
